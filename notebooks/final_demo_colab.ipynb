# %% [markdown]
# # Turkish Legal RAG Assistant - Final Demo
#
# This notebook runs the final submission package on Google Colab.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# %cd /content/drive/MyDrive/turkish-legal-rag-pipeline-feat-baseline-rag-arda/baseline_rag/FINAL_SUBMISSION

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## Light Smoke Test
# Use this if GPU memory is limited.

# %%
# !python smoke_test_light.py

# %% [markdown]
# ## Full Smoke Test
# This loads the full retriever, reranker and generator. It may use around 12 GB GPU memory.

# %%
# !python smoke_test.py

# %% [markdown]
# ## Run Manual UI
# The UI supports legal knowledge-base QA and uploaded document QA.

# %%
exec(open('final_ui.py', encoding='utf-8').read())
